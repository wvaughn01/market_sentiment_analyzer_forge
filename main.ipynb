# %%
# Import required modules
import pandas as pd
import numpy as np
import time
import yfinance as yf
from datetime import datetime, timedelta
import joblib

from sentiment_utils import FinancialNewsAggregator
from features import compute_behavioral_features, label_reaction
from model_train import train_behavioral_model

# %%
def get_sp500_tickers():
    try:
        url = "https://datahub.io/core/s-and-p-500-companies/r/constituents.csv"
        df = pd.read_csv(url)
        return df['Symbol'].tolist()
    except Exception as e:
        print("❌ Failed to get tickers:", e)
        return []

raw_tickers = get_sp500_tickers()
print(f"✅ Pulled {len(raw_tickers)} raw tickers")
# Out:
# ✅ Pulled 503 raw tickers

# %%
end = datetime.today()
start = end - timedelta(days=30)

# %%
def is_ticker_valid(ticker):
    try:
        df = yf.download(ticker, start=start, end=end, progress=False)
        return not df.empty and 'Close' in df.columns and df['Close'].notnull().any()
    except Exception:
        return False

tickers = [t for t in raw_tickers if is_ticker_valid(t)]
tickers = tickers[:10]  # limit to 10 for test
print(f"✅ Valid tickers: {tickers}")
# Out:
# Failed to get ticker 'MMM' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['MMM']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AOS' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AOS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ABT' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ABT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ABBV' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ABBV']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ACN' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ACN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ADBE' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ADBE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AMD' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AMD']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AES' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AES']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AFL' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AFL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'A' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['A']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'APD' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['APD']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ABNB' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ABNB']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AKAM' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AKAM']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ALB' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ALB']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ARE' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ARE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ALGN' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ALGN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ALLE' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ALLE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'LNT' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['LNT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ALL' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ALL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'GOOGL' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['GOOGL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'GOOG' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['GOOG']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'MO' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['MO']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AMZN' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AMZN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AMCR' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AMCR']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AEE' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AEE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AEP' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AEP']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AXP' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AXP']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AIG' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AIG']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AMT' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AMT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AWK' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AWK']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AMP' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AMP']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AME' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AME']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AMGN' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AMGN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'APH' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['APH']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ADI' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ADI']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AON' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AON']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'APA' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['APA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'APO' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['APO']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AAPL' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AAPL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AMAT' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AMAT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'APTV' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['APTV']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ACGL' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ACGL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ADM' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ADM']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ANET' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ANET']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AJG' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AJG']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AIZ' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AIZ']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'T' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['T']: YF%ticker%zMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ATO' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ATO']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ADSK' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ADSK']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'ADP' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['ADP']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AZO' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AZO']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AVB' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AVB']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AVY' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AVY']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AXON' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AXON']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BKR' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BKR']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BALL' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BALL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BAC' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BAC']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BAX' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BAX']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BDX' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BDX']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BRK.B' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BBY' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BBY']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'TECH' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['TECH']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BIIB' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BIIB']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BLK' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BLK']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BX' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BX']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'XYZ' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['XYZ']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BK' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BK']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BA' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BKNG' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BKNG']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BSX' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BSX']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'BMY' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BMY']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# Failed to get ticker 'AVGO' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AVGO']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       6         return False
#       8 # Filter good tickers
# ----> 9 tickers = [t for t in raw_tickers if is_ticker_valid(t)]
#      10 tickers = tickers[:10]  # Limit to top 10 for speed
#      11 print(f"✅ Valid tickers: {tickers}")
#
# Cell In[9], line 3, in is_ticker_valid(ticker)
#       1 def is_ticker_valid(ticker):
#       2     try:
# ----> 3         df = yf.download(ticker, start=start, end=end, progress=False)
#       4         return not df.empty and 'Close' in df.columns and df['Close'].notnull().any()
#       5     except Exception:
#
# File c:\VS_Code\Behavioral_Econ_ML\.venv\Lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File c:\VS_Code\Behavioral_Econ_ML\.venv\Lib\site-packages\yfinance\multi.py:152, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, interval, prepost, proxy, rounding, timeout, session)
#     145         _download_one_threaded(ticker, period=period, interval=interval,
#     146                                start=start, end=end, prepost=prepost,
#     147                                actions=actions, auto_adjust=auto_adjust,
#     148                                back_adjust=back_adjust, repair=repair, keepna=keepna,
#     149                                progress=(progress and i > 0), proxy=proxy,
#     150                                rounding=rounding, timeout=timeout)
#     151     while len(shared._DFS) < len(tickers):
# --> 152         _time.sleep(0.01)
#     153 # download synchronously
#     154 else:
#     155     for i, ticker in enumerate(tickers):
#
# KeyboardInterrupt:
# Failed to get ticker 'BR' reason: Expecting value: line 1 column 1 (char 0)

# %%
records = []
news_aggregator = FinancialNewsAggregator()

# %%
def safe_yfinance_download(ticker, start, end, retries=2):
    """
    Attempts to download ticker data safely.
    Returns empty DataFrame on failure.
    """
    for attempt in range(retries):
        try:
            df = yf.download(ticker, start=start, end=end, progress=False)
            if df.empty or df.isnull().all().all() or 'Close' not in df.columns:
                raise ValueError("Empty or invalid data frame")
            return df
        except Exception as e:
            print(f"⚠️ Attempt {attempt+1} failed for {ticker}: {e}")
            time.sleep(1)
    print(f"❌ Giving up on {ticker} after {retries} attempts.")
    return pd.DataFrame()

# %%
for ticker in tickers:
    print(f"\n▶ Processing: {ticker}")
    time.sleep(1)

    # 🟩 Market Data
    df = safe_yfinance_download(ticker, start, end)
    if df.empty:
        continue
    df = compute_behavioral_features(df)

    # ✅ Sentiment Data
    try:
        news_data = news_aggregator.get_sentiment_data(
            ticker,
            start.strftime("%Y-%m-%d"),
            end.strftime("%Y-%m-%d")
        )
        if news_data.empty:
            print(f"⚠️ No news for {ticker}")
            continue
    except Exception as e:
        print(f"⚠️ Sentiment error: {e}")
        continue

    # ✅ Sentiment Delta
    pre_news = news_data[news_data['date'] < end - timedelta(days=15)]
    post_news = news_data[news_data['date'] >= end - timedelta(days=15)]
    delta = news_aggregator.get_avg_sentiment(post_news) - news_aggregator.get_avg_sentiment(pre_news)
    label = label_reaction(delta)

    # ✅ Final Record
    records.append({
        "ticker": ticker,
        "event_date": end.strftime("%Y-%m-%d"),
        "price_change": df['price_change'].mean(),
        "volatility": df['volatility'].mean(),
        "loss_aversion_score": df['loss_aversion_score'].mean(),
        "reaction_speed": df['reaction_speed'].mean(),
        "herding_index": df['herding_index'].mean(),
        "sentiment_delta": delta,
        "reaction_label": label
    })
# Out:
# ▶ Processing: MMM
# Failed to get ticker 'MMM' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['MMM']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ❌ No market data.
#
# ▶ Processing: AOS
# Failed to get ticker 'AOS' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AOS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ❌ No market data.
#
# ▶ Processing: ABT
# Failed to get ticker 'ABT' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ❌ No market data.
#
# ▶ Processing: ABBV
# Failed to get ticker 'ABBV' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABBV']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ❌ No market data.
#
# ▶ Processing: ACN
# Failed to get ticker 'ACN' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ❌ No market data.

# %%
df_final = pd.DataFrame(records)
df_final.to_csv("live_training_data.csv", index=False)
df_final.head()

# %%
if df_final.empty:
    print("❌ No data collected. Skipping model training.")
else:
    model = train_behavioral_model(df_final)
    joblib.dump(model, "trained_behavioral_model.pkl")
    print("✅ Model saved to trained_behavioral_model.pkl")

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(model)
plt.title("Feature Importance")
plt.tight_layout()
plt.show()
